# %%
import quantstats as qs

# %%
stock = qs.utils.download_returns('TQQQ')

# %%
stock
# Out:
# Date
# 2010-02-11         NaN
# 2010-02-12    0.004094
# 2010-02-16    0.038734
# 2010-02-17    0.016970
# 2010-02-18    0.018958
#                 ...
# 2022-10-19   -0.012133
# 2022-10-20   -0.016889
# 2022-10-21    0.070796
# 2022-10-24    0.034030
# 2022-10-25    0.060179
# Name: Close, Length: 3199, dtype: float64

# %%
for year in range(2010,2023):
    for month in range(9,11):
        sell_month =f'{year}-{month}'
        stock.loc[sell_month]=0

# %%
stock.loc['2022-8']
# Out:
# Date
# 2022-08-01    0.0
# 2022-08-02    0.0
# 2022-08-03    0.0
# 2022-08-04    0.0
# 2022-08-05    0.0
# 2022-08-08    0.0
# 2022-08-09    0.0
# 2022-08-10    0.0
# 2022-08-11    0.0
# 2022-08-12    0.0
# 2022-08-15    0.0
# 2022-08-16    0.0
# 2022-08-17    0.0
# 2022-08-18    0.0
# 2022-08-19    0.0
# 2022-08-22    0.0
# 2022-08-23    0.0
# 2022-08-24    0.0
# 2022-08-25    0.0
# 2022-08-26    0.0
# 2022-08-29    0.0
# 2022-08-30    0.0
# 2022-08-31    0.0
# Name: Close, dtype: float64

# %%
qs.reports.full(stock)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2010-02-11
# End Period                 2022-10-25
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          5,126.31%
# CAGR﹪                     36.52%
#
# Sharpe                     0.82
# Prob. Sharpe Ratio         99.81%
# Smart Sharpe               0.75
# Sortino                    1.15
# Smart Sortino              1.05
# Sortino/√2                 0.81
# Smart Sortino/√2           0.74
# Omega                      1.16
#
# Max Drawdown               -80.16%
# Longest DD Days            431
# Volatility (ann.)          60.89%
# Calmar                     0.46
# Skew                       -0.47
# Kurtosis                   6.26
#
# Expected Daily %           0.12%
# Expected Monthly %         2.62%
# Expected Yearly %          35.57%
# Kelly Criterion            7.81%
# Risk of Ruin               0.0%
# ...

# %%
36.52/265
# Out:
# 0.137811320754717

# %%
qs.reports.full(stock)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2010-02-11
# End Period                 2022-10-25
# Risk-Free Rate             0.0%
# Time in Market             83.0%
#
# Cumulative Return          3,073.61%
# CAGR﹪                     31.26%
#
# Sharpe                     0.77
# Prob. Sharpe Ratio         99.67%
# Smart Sharpe               0.7
# Sortino                    1.08
# Smart Sortino              0.98
# Sortino/√2                 0.76
# Smart Sortino/√2           0.69
# Omega                      1.17
#
# Max Drawdown               -75.32%
# Longest DD Days            707
# Volatility (ann.)          55.66%
# Calmar                     0.42
# Skew                       -0.47
# Kurtosis                   9.11
#
# Expected Daily %           0.11%
# Expected Monthly %         2.29%
# Expected Yearly %          30.47%
# Kelly Criterion            8.19%
# Risk of Ruin               0.0%
# ...

# %%
31.26/200
# Out:
# 0.1563

# %%
qs.reports.full(stock)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2010-02-11
# End Period                 2022-10-25
# Risk-Free Rate             0.0%
# Time in Market             74.0%
#
# Cumulative Return          2,906.74%
# CAGR﹪                     30.71%
#
# Sharpe                     0.78
# Prob. Sharpe Ratio         99.69%
# Smart Sharpe               0.69
# Sortino                    1.09
# Smart Sortino              0.97
# Sortino/√2                 0.77
# Smart Sortino/√2           0.69
# Omega                      1.18
#
# Max Drawdown               -75.32%
# Longest DD Days            511
# Volatility (ann.)          52.43%
# Calmar                     0.41
# Skew                       -0.45
# Kurtosis                   11.08
#
# Expected Daily %           0.11%
# Expected Monthly %         2.25%
# Expected Yearly %          29.93%
# Kelly Criterion            8.69%
# Risk of Ruin               0.0%
# ...

# %%
30.71/178
# Out:
# 0.17252808988764046

# %%
qs.reports.html(stock, output='./tqqq1234.html')
